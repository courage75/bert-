# %%
import pandas as pd
df=pd.read_excel('weibo.xlsx')
df
# Out:
#                                                 comment  label
# 0     是的，这游戏全靠炒作，一个神话背景的游戏，打斗场面和街头霸王差不多，哪个智力正常的玩家会真觉...     -1
# 1                                唉，中肯的评价，就是现在这游戏听不了一点批评     -1
# 2                 我倒是觉得既然有了不错的收益，后续就应该拿出更好一些的作品，改善前作的缺点      0
# 3     贫僧亦感同身受，若非西游之名，此作恐难引起共鸣。幸得猴王魅力，方有今日之盛。望创作者能以故事...      1
# 4     这游戏后期粪怪太多，无论你操作如何强制拉你进入他的回合，故意拉长战斗时间，打着真的是非常非常...     -1
# ...                                                 ...    ...
# 4626                            不觉得，我一个不玩游戏的反而是被剧情深深吸引。      0
# 4627                               麻烦先下个游戏 不然你这种治好了也流口水      0
# 4628  去看看冯骥的采访，他说不见得是这游戏多好多完美，很大程度是机缘到了出现这款游戏而受欢迎，很多...     -1
# 4629                                            来看生物多样性      0
# 4630                                          到哪了[doge]      0
#
# [4631 rows x 2 columns]

# %%
import re

def remove_emojis(text):
    # Emoji表情的Unicode范围，这个范围可能需要根据实际情况进行调整
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "]+", flags=re.UNICODE)

    # 替换文本中的Emoji表情为空字符串
    return emoji_pattern.sub('', text)

df['comment']=df['comment'].apply(remove_emojis)
df.to_excel('weibo.xlsx',index=False)
